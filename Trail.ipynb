# %% [markdown]
# #Trial

# %%
a=4
b=2
c=a+b
print(c)
# Out:
# 6

# %%
print("hellow wordl")
# Out:
# hellow wordl

# %%
class Myclass:
    def func(x):
        return x*x
a=Myclass
abc=a.func(2)
abc
# Out:
# 4
